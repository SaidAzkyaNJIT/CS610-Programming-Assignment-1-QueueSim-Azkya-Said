# %% [markdown]
# The simulation is currently setup for 100 minutes, 1 customer per minute arriving on average, and a service time of 5 days. Different parameters were tested, and these were selected for ease of analysis.
#
# Key Observations:
#
# Fastest System: The single queue system appears to be the fastest, completing the simulation in a shorter duration compared to the multiple queue scenarios. This is because all three service stations can potentially be utilized simultaneously in a single queue system, whereas multiple queues can lead to idle stations if one queue is empty while others are still populated.
#
# Queue Lengths and Waiting Times: While the multiple queue systems had shorter average queue lengths compared to the single queue, they exhibited slightly longer average waiting times. This can be attributed to the fact that even with shorter queues, customers may still need to wait for a specific service station to become available in the multiple queue scenarios.
#
# Multiple Queue Strategies: Among the multiple queue strategies, round-robin tends to perform the best due to its balanced distribution of customers across the queues. Random assignment can lead to the worst performance due to the possibility of uneven queue buildup if customers are repeatedly assigned to the same queue. The rate of occupancy was also more consistent across the 3 service stations for the round robin. This shows that round robin was the most efficient of the multiple queuing startegies.
# Conclusion:
#
# Based on this simulation, a single queue system seems to be more efficient in terms of overall throughput (duration) and potentially customer satisfaction (shorter maximum waiting times). However, if multiple queues are necessary due to factors like service specialization or physical constraints, a round-robin assignment strategy is likely to yield the best results among the multiple queue options. The choice between single and multiple queues may depend on additional factors not considered in this simulation, such as customer preferences, the nature of the services being offered, and the physical layout of the service area.

# %%
# %run qsimsetup.ipynb

#d is the duration in minutes that the customers will arrive at the queues
#ar, arrival rate, represents on average after how many minutes a new customer will appear
#s, is the service rate on average. This represents how many minutes a service will take on average. 

d = 100
ar = 1
s = 5

print('-----Single Queue Simulation:-----\n')
sim1(d,ar,s)
print('\n-----Three Queues Random Assignment:-----\n')
sim2(d,ar,s)
print('\n-----Three Queues Round Robin:-----\n')
sim3(d,ar,s)
print('\n-----Three Queues Assign to Shortest Queue:-----\n')
sim4(d,ar,s)
# Out:
# -----Single Queue Simulation:-----
#
# Duration: 146 mins
# 100 customers
# Approximately one customer every 1 minutes
#
# Station 1 served: 32
# Station 2 served: 34
# Station 3 served: 34
#
# Max q size: 34
# Station 1 Rate of Occupancy: 0.79
# Station 2 Rate of Occupancy: 0.77
# Station 3 Rate of Occupancy: 0.76
#
# Avg service time: 4.5 mins
# Average Waiting Time: 22.9 mins
# Maximum Waiting Time: 47 mins
#
# -----Three Queues Random Assignment:-----
#
# Duration: 199 mins
# 100 customers
# Approximately one new customer every 1 minutes
#
# Station 1 served: 30
# Station 2 served: 38
# Station 3 served: 32
#
# Max q1 size: 15
# Max q2 size: 19
# Max q3 size: 10
#
# Station 1 Rate of Occupancy: 0.71
# Station 2 Rate of Occupancy: 0.81
# Station 3 Rate of Occupancy: 0.56
#
# Avg service time: 5.1 mins
# Average Waiting Time: 37.8 mins
# Maximum Waiting Time: 99 mins
#
# -----Three Queues Round Robin:-----
#
# Duration: 172 mins
# 100 customers
# ...
